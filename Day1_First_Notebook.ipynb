# %%
import matplotlib.pyplot as plt

# Simple graph: y = x²
x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]

plt.plot(x, y, marker="o", color="blue")
plt.title("First Notebook Graph")
plt.xlabel("X values")
plt.ylabel("Y squared")
plt.grid(True)
plt.show()
